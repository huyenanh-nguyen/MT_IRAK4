# %%
from cellpose import io, models, train

# %%
import torch

print("PyTorch:", torch.__version__)
print("MPS available:", torch.backends.mps.is_available())
print("CUDA available:", torch.cuda.is_available())
# Out:
# PyTorch: 2.13.0
# MPS available: True
# CUDA available: False

# %%
import importlib.metadata
from cellpose import io
import inspect

print("Cellpose version:", importlib.metadata.version("cellpose"))
print("load_train_test_data:")
print(inspect.signature(io.load_train_test_data))
# Out:
# Cellpose version: 4.2.1.1
# load_train_test_data:
# (train_dir, test_dir=None, image_filter=None, mask_filter='_masks', look_one_level_down=False)

# %%
train_dir = "/Users/huyenanh/git_repos/MT_IRAK4/gfp_rollingball/rfp_rollingball_train"
test_dir = "/Users/huyenanh/git_repos/MT_IRAK4/gfp_rollingball/rfp_rollingball_test"

# %%
from cellpose import io

io.logger_setup()

output = io.load_train_test_data(
    str(train_dir),
    str(test_dir),
    image_filter=None,
    mask_filter="_masks",
    look_one_level_down=False
)

images, labels, image_names, test_images, test_labels, image_names_test = output

print("Training images:", len(images))
print("Training masks:", len(labels))
print("Test images:", len(test_images))
print("Test masks:", len(test_labels))

print("\nTraining files:")
for name in image_names:
    print(name)

print("\nTest files:")
for name in image_names_test:
    print(name)
# Out:
# [GUI INFO] : WRITING LOG OUTPUT TO /Users/huyenanh/.cellpose/run.log
#
# cellpose version: 	4.2.1.1
# platform:       	darwin
# python version: 	3.11.6
# torch version:  	2.13.0
# 2026-08-11 16:20:17,271 [io INFO] WRITING LOG OUTPUT TO /Users/huyenanh/.cellpose/run.log
# 2026-08-11 16:20:17,272 [io INFO]
# cellpose version: 	4.2.1.1
# platform:       	darwin
# python version: 	3.11.6
# torch version:  	2.13.0
# 2026-08-11 16:20:17,278 [io INFO] not all flows are present, running flow generation for all images
# 2026-08-11 16:20:17,316 [io INFO] 7 / 7 images in /Users/huyenanh/git_repos/MT_IRAK4/gfp_rollingball/rfp_rollingball_train folder have labels
# 2026-08-11 16:20:17,318 [io INFO] not all flows are present, running flow generation for all images
# 2026-08-11 16:20:17,320 [io INFO] 1 / 1 images in /Users/huyenanh/git_repos/MT_IRAK4/gfp_rollingball/rfp_rollingball_test folder have labels
# Training images: 7
# Training masks: 7
# Test images: 1
# Test masks: 1
#
# Training files:
# /Users/huyenanh/git_repos/MT_IRAK4/gfp_rollingball/rfp_rollingball_train/rfp_rollingball_0000.tif
# /Users/huyenanh/git_repos/MT_IRAK4/gfp_rollingball/rfp_rollingball_train/rfp_rollingball_0020.tif
# /Users/huyenanh/git_repos/MT_IRAK4/gfp_rollingball/rfp_rollingball_train/rfp_rollingball_0040.tif
# /Users/huyenanh/git_repos/MT_IRAK4/gfp_rollingball/rfp_rollingball_train/rfp_rollingball_0060.tif
# /Users/huyenanh/git_repos/MT_IRAK4/gfp_rollingball/rfp_rollingball_train/rfp_rollingball_0080.tif
# /Users/huyenanh/git_repos/MT_IRAK4/gfp_rollingball/rfp_rollingball_train/rfp_rollingball_0100.tif
# /Users/huyenanh/git_repos/MT_IRAK4/gfp_rollingball/rfp_rollingball_train/rfp_rollingball_0120.tif
#
# Test files:
# /Users/huyenanh/git_repos/MT_IRAK4/gfp_rollingball/rfp_rollingball_test/rfp_rollingball_0120.tif

# %%
io.logger_setup()
output = io.load_train_test_data(
    train_dir,
    test_dir,
    image_filter = None,
    mask_filter="_masks",
    look_one_level_down=False
)
images, labels, image_names, test_images, test_labels, image_names_test = output

model = models.CellposeModel(gpu=True)

model_path, train_losses, test_losses = train.train_seg(model.net,
                            train_data=images, train_labels=labels,
                            test_data=test_images, test_labels=test_labels,
                            weight_decay=0.1, learning_rate=1e-5,
                            n_epochs=100, model_name="my_new_model")
# Out:
# [GUI INFO] : WRITING LOG OUTPUT TO /Users/huyenanh/.cellpose/run.log
#
# cellpose version: 	4.2.1.1
# platform:       	darwin
# python version: 	3.11.6
# torch version:  	2.13.0
# 2026-08-11 16:20:53,028 [io INFO] WRITING LOG OUTPUT TO /Users/huyenanh/.cellpose/run.log
# 2026-08-11 16:20:53,029 [io INFO]
# cellpose version: 	4.2.1.1
# platform:       	darwin
# python version: 	3.11.6
# torch version:  	2.13.0
# 2026-08-11 16:20:53,033 [io INFO] not all flows are present, running flow generation for all images
# 2026-08-11 16:20:53,056 [io INFO] 7 / 7 images in /Users/huyenanh/git_repos/MT_IRAK4/gfp_rollingball/rfp_rollingball_train folder have labels
# 2026-08-11 16:20:53,061 [io INFO] not all flows are present, running flow generation for all images
# 2026-08-11 16:20:53,068 [io INFO] 1 / 1 images in /Users/huyenanh/git_repos/MT_IRAK4/gfp_rollingball/rfp_rollingball_test folder have labels
# 2026-08-11 16:20:53,151 [core INFO] ** TORCH MPS version installed and working. **
# 2026-08-11 16:20:53,152 [core INFO] >>>> using GPU (MPS)
# 2026-08-11 16:20:54,705 [models INFO] >>>> loading model /Users/huyenanh/.cellpose/models/cpsam_v2
# 2026-08-11 16:20:56,046 [train INFO] >>> converting bfloat16 network to float32 for training
# 2026-08-11 16:20:56,074 [dynamics INFO] computing flows for labels
# 100%|██████████| 7/7 [00:02<00:00,  3.07it/s]
# 2026-08-11 16:20:58,372 [dynamics INFO] computing flows for labels
# 2026-08-11 16:20:58,644 [train INFO] >>> computing diameters
# 100%|██████████| 7/7 [00:00<00:00, 579.23it/s]
# 100%|██████████| 1/1 [00:00<00:00, 491.14it/s]
# 2026-08-11 16:20:58,661 [train INFO] >>> normalizing {'lowhigh': None, 'percentile': None, 'normalize': True, 'norm3D': True, 'sharpen_radius': 0, 'smooth_radius': 0, 'tile_norm_blocksize': 0, 'tile_norm_smooth3D': 1, 'invert': False}
# 2026-08-11 16:20:58,729 [train INFO] >>> n_epochs=100, n_train=7, n_test=1, bsize=256, batch_size=1, nimg_per_epoch=7
# 2026-08-11 16:20:58,729 [train INFO] >>> AdamW, learning_rate=0.00001, weight_decay=0.10000
# 2026-08-11 16:20:58,731 [train INFO] >>> saving model to /Users/huyenanh/git_repos/MT_IRAK4/models/my_new_model
# /Users/huyenanh/git_repos/MT_IRAK4/env/lib/python3.11/site-packages/cellpose/train.py:466: UserWarning: In MPS autocast, but the target dtype is not supported. Disabling autocast.
# MPS Autocast only supports dtypes of torch.bfloat16, torch.float16 currently.
#   with torch.autocast(device_type=device.type, dtype=net.dtype):
# /Users/huyenanh/git_repos/MT_IRAK4/env/lib/python3.11/site-packages/cellpose/train.py:509: UserWarning: In MPS autocast, but the target dtype is not supported. Disabling autocast.
# MPS Autocast only supports dtypes of torch.bfloat16, torch.float16 currently.
#   with torch.autocast(device_type=device.type, dtype=net.dtype):
# 2026-08-11 16:21:12,592 [train INFO] 0, train_loss=3.7079, test_loss=2.7018, LR=0.000000, time 13.86s
# 2026-08-11 16:22:01,546 [train INFO] 5, train_loss=3.1653, test_loss=2.0159, LR=0.000006, time 62.81s
# 2026-08-11 16:22:50,477 [train INFO] 10, train_loss=2.3070, test_loss=1.9146, LR=0.000010, time 111.74s
# 2026-08-11 16:24:24,587 [train INFO] 20, train_loss=2.1845, test_loss=1.6939, LR=0.000010, time 205.86s
# 2026-08-11 16:25:58,595 [train INFO] 30, train_loss=1.9860, test_loss=1.6671, LR=0.000010, time 299.86s
# 2026-08-11 16:27:33,282 [train INFO] 40, train_loss=2.0532, test_loss=1.5696, LR=0.000010, time 394.55s
# 2026-08-11 16:29:08,233 [train INFO] 50, train_loss=1.9780, test_loss=1.4938, LR=0.000005, time 489.50s
# 2026-08-11 16:30:43,993 [train INFO] 60, train_loss=2.0522, test_loss=1.4792, LR=0.000001, time 585.26s
# 2026-08-11 16:32:20,458 [train INFO] 70, train_loss=2.0828, test_loss=1.4807, LR=0.000000, time 681.73s
# 2026-08-11 16:33:54,833 [train INFO] 80, train_loss=1.8480, test_loss=1.4774, LR=0.000000, time 776.10s
# 2026-08-11 16:35:31,494 [train INFO] 90, train_loss=1.9185, test_loss=1.4781, LR=0.000000, time 872.76s
# 2026-08-11 16:36:58,198 [train INFO] saving network parameters to /Users/huyenanh/git_repos/MT_IRAK4/models/my_new_model
# 2026-08-11 16:37:01,584 [train INFO] >>> converting network back to torch.bfloat16 after training
